# %% [markdown]
# # Task 1
#
# Extract a subset of traning samples from the MNIST handwriten signatures. Create a small convolution neural network with two convolution layers, two pool layers, flatten, dense layer and softmax layer to classify the images. Find out classification error for learning set and testing set.

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

(x_train,y_train),(x_test,y_test) = tf.keras.datasets.mnist.load_data()

print(x_train.shape)
print(x_test.shape)
x_train = x_train[:10000]
y_train = y_train[:10000]

x_train = x_train.reshape(x_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/ 255

y_train = to_categorical(y_train, num_classes = 10)
y_test = to_categorical(y_test, num_classes = 10)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# array([5, 0, 4, ..., 6, 9, 7], dtype=uint8)

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

(x_train,y_train),(x_test,y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train[:10000]
y_train = y_train[:10000]

x_train = x_train.reshape((x_train.shape[0],28,28,1))
x_test = x_test.reshape((x_test.shape[0],28,28,1))

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

y_train = to_categorical(y_train, num_classes = 10)
y_test = to_categorical(y_test, num_classes =10)

print(x_train.shape)
model  = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(10,kernel_size = (4,4), activation='relu', input_shape = (28,28,1)))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Conv2D(32, kernel_size=(4,4),activation='relu',))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs = 10, batch_size = 400)
# Out:
# (10000, 28, 28, 1)
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.4245 - loss: 1.9895
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.8152 - loss: 0.6533
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.8981 - loss: 0.3603
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9272 - loss: 0.2518
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9393 - loss: 0.2164
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9561 - loss: 0.1568
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9539 - loss: 0.1483
# ...

# %%
train_loss, train_accuracy = model.evaluate(x_train,y_train)
test_loss, test_accuracy = model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9734 - loss: 0.0903
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9602 - loss: 0.1268
# 0.9666000008583069

# %%
print("train error", round(1-train_accuracy,2))
print("test_error", (1-test_accuracy))
# Out:
# train error 0.03
# test_error 0.033399999141693115

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

(x_train, y_train), (x_test,y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

print(x_train.shape)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(10,(4,4),activation = 'relu'))
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(10, activation='softmax'))

model.compile(loss = 'categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
model.fit(x_train, y_train, epochs=2, batch_size=128)
# Out:
# (60000, 28, 28, 1)
# Epoch 1/2
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 0.7617 - loss: 0.8436
# Epoch 2/2
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9448 - loss: 0.1943

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# # Task 2
#
# Create an autoencoder for MNIST fashion dataset. The input and the output is the same image of a number 28x28 pixels.

# %%
# Example
import tensorflow as tf
import numpy as np
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import random as rnd
import numpy as np
# Prepare a subset of the data
t_x = []
t_y = []
sz = len(train_images)
print(f"Total training images: {sz}")

for i in range(20):
    idx = rnd.randint(0, sz-1)
    for c in range(10):
        while train_labels[idx] != c:
            idx = rnd.randint(0, sz-1)
        t_x.append(np.ndarray.flatten(train_images[idx]))
        t_y.append(train_labels[idx])

t_x = np.array(t_x, dtype=np.float32) / 255.0
t_y = np.array(t_y, dtype=np.int32)
print(f"Subset shape (features): {t_x.shape}")
print(f"Subset shape (labels): {t_y.shape}")
# Out:
# Total training images: 60000
# Subset shape (features): (200, 784)
# Subset shape (labels): (200,)

# %%
t_x = train_images[:500]
t_x = np.array(t_x)
t_x= t_x.flatten()
t_x = t_x/255

# %%
# Out:
# (392000,)

# %% [markdown]
# ## Subtask 1
#
#  Use two dense layers (hidden and output). Hidden layer with 2 neurons, output layer with 784 neurons. Plot the response of hidden neurons in scatter plot, number categories distinquish by colors.

# %%
import matplotlib.pyplot as plt

inputs = tf.keras.layers.Input(shape=(784,))
hidden_layer = tf.keras.layers.Dense(2, activation='relu')(inputs)
outputs = tf.keras.layers.Dense(784, activation='sigmoid')(hidden_layer)

model = tf.keras.Model(inputs=inputs, outputs=outputs)
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['accuracy'])
model.fit(t_x, t_x, epochs=20, batch_size = 2048)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step - accuracy: 0.0000e+00 - loss: 0.1688
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.0000e+00 - loss: 0.1686
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.0000e+00 - loss: 0.1684
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.0000e+00 - loss: 0.1682
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0000e+00 - loss: 0.1680
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.0000e+00 - loss: 0.1677
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0000e+00 - loss: 0.1674
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.0000e+00 - loss: 0.1671
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.0000e+00 - loss: 0.1668
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0000e+00 - loss: 0.1664
# Epoch 11/20
# ...

# %%
model.summary()
# Out:
# Model: "functional_46"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)          │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 2)                   │           1,570 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 784)                 │           2,352 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,768 (45.97 KB)
#  Trainable params: 3,922 (15.32 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,846 (30.65 KB)

# %%
hidden_layer_model = tf.keras.Model(inputs=model.input, outputs=model.layers[1].output)
hidden_layer_output = hidden_layer_model.predict(t_x)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ec5562f4f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(hidden_layer_output[:, 0], hidden_layer_output[:, 1], c=t_y, cmap='jet',alpha = 0.6)
plt.colorbar(scatter)
plt.xlabel('Hidden Layer Neuron 1 Response')
plt.ylabel('Hidden Layer Neuron 2 Response')
plt.title('Hidden Layer Responses')
plt.grid()
plt.show()

# %% [markdown]
# ## Subtask 2
#
# Modify Subtask 1 so that you add three hidden layers and 2 latent features, i.e.
# 784-10-2-10-784 neurons. Observe differences.

# %%
input = tf.keras.layers.Input(shape=(784,))
hid1 = tf.keras.layers.Dense(10, activation='relu')(input)
hid2 = tf.keras.layers.Dense(2, activation = 'relu')(hid1)
hid3 = tf.keras.layers.Dense(10, activation='relu')(hid2)
output = tf.keras.layers.Dense(784, activation = 'sigmoid')(hid3)

model = tf.keras.Model(inputs = input, outputs = output)
model.compile(loss = 'mse', optimizer='Adam', metrics=['accuracy'])
model.fit(t_x,t_x, epochs =10, batch_size =128)
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.0000e+00 - loss: 0.1711
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0059 - loss: 0.1725
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0059 - loss: 0.1712
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0059 - loss: 0.1707
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0059 - loss: 0.1687
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0059 - loss: 0.1682
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0033 - loss: 0.1661
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0059 - loss: 0.1644
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0059 - loss: 0.1629
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0059 - loss: 0.1606

# %%
model.summary()
# Out:
# Model: "functional_57"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_20 (InputLayer)          │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 10)                  │           7,850 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_50 (Dense)                     │ (None, 2)                   │              22 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_51 (Dense)                     │ (None, 10)                  │              30 │
# ...

# %%
latent_layer = tf.keras.Model(inputs = model.input, outputs = model.layers[2].output)
latent_layer_output = latent_layer.predict(t_x)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
plt.scatter(latent_layer_output[:,0],latent_layer_output[:,1], c = t_y, cmap='jet')

# %% [markdown]
# ## Subtask 3
#
# Modify Subtask 1 so that you add convolution layers, pooling layers, ... for the autoencoder and observe differences.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images = train_images[:5000]
test_images = test_images[:5000]
t_x = t_x.reshape((t_x.shape[0],28,28,1))

train_images = train_images.astype('float32')/255
test_images = test_images.astype('float32')/255

# Define the Convolutional Autoencoder
input_img = tf.keras.layers.Input(shape=(28, 28, 1))

# Encoder
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)


# Create the autoencoder model
autoencoder = tf.keras.Model(input_img, decoded)

# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder.fit(t_x, t_x, epochs=10, batch_size=128)

# Create a new model to output the encoder layer activations
encoder_model = tf.keras.Model(inputs=autoencoder.input, outputs=encoded)

# Get the outputs from the encoder
encoder_outputs = encoder_model.predict(t_x)

# Reshape encoder outputs for scatter plot
encoder_outputs_reshaped = encoder_outputs.reshape(len(t_x), -1)  # Flatten to 2D

# Scatter plot of encoder layer responses
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.6894
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.6834
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.6766
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.6697
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.6628
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.6547
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.6450
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.6331
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.6203
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.6064
# ...

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(encoder_outputs_reshaped[:, 0], encoder_outputs_reshaped[:, 1], c=t_y, cmap='viridis', alpha=0.5)
plt.title('Encoder Layer Outputs')
plt.xlabel('Feature 1 Output')
plt.ylabel('Feature 2 Output')
plt.colorbar(scatter, label='Categories')
plt.grid()
plt.show()

# %% [markdown]
# ## Subtask 4
#
# Extract the decoder from the autoencoder of subtask 1-3 and generate new images based on randomly generated latent features. Plot generated images.

# %%
# Decoder
x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
